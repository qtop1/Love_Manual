# %%
#CAN ONLY SEARCH THE LAST 6–9 days as maximum.
#THERE SEEMS TO BE A LIMIT ON THE TWEETS I HAVE
#IM CURRENTLY TRYING TO GET A CSV FILE OF FULL TEXT TWEETS WITH ID

#################################################
################################################

#Filter for specific Places by their name or ID. 
#To discover “Places” associated with a specific area,
#use Twitter's reverse_geocode endpoint in the REST API. 
import configparser
import tweepy

from T_config import *

import requests
import json
import pandas as pd


import nltk
nltk.download('stopwords')
nltk.download('vader_lexicon')
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import string

import csv

import spacy
from scipy import spatial
import matplotlib.pyplot as plt
import numpy as np
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jalisaabeid/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jalisaabeid/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
nlp = spacy.load('en_core_web_lg')

# %%
#Through research only have access to v1
#need to have time to sleep in between as too much overload
#use THIS :: api = tweepy.API(auth,wait_on_rate_limit=True)
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)


#homepage
#public_tweets = api.home_timeline()

#keywords 

#for i in range (10):
#    print(public_tweets[i].text)

tweets = api.search_tweets(
    q="#covid",
    count=10
)
#print(tweets)

# %%
json_data = [r._json for r in tweets]

df = pd.json_normalize(json_data)

# %%
######################################################

# %%
#CONVERT TWEETS INTO CSV FILE
#USE THIS EXAMPLE AS DISPLAYING FULL TEXT
csvFile = open('testing_testing.csv', 'a')

#Use csv writer
csvWriter = csv.writer(csvFile)

for tweet in api.search_tweets(q = "google",lang = "en",count=50):
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print( tweet.created_at, tweet.text)
csvFile.close()
#df = pd.read_csv("imdbTop250.csv")
# Out:
# 2023-05-01 17:59:52+00:00 RT @PopBase: “The idea that this stuff could actually get smarter than people — a few people believed that. But most people thought it was…
# 2023-05-01 17:59:51+00:00 @polo_kimanii @Ke_nedo Before you start googling, divide your project to 100 - 100,000 pieces depending on complexi… https://t.co/jUE5oF8RJN
# 2023-05-01 17:59:51+00:00 RT @gdgcloudkol: Welcome, @hack4bengal, as our community partner for Google Cloud CommunityDays, Kolkata ‘23.
# A day full of tech sessions,…
# 2023-05-01 17:59:51+00:00 RT @ZainabAlerts: M Adeel was found safe and reunited with his family !!! #ZainabAlert #ZainabAlertApp
#
# Thanks for sharing, Please download…
# 2023-05-01 17:59:51+00:00 RT @taeguide: [VOTE] Our lead is again in danger on Idol champ. Widen the gap on Idol champ to 5K and gap on Fancast to 20K
#
# Don’t be comp…
# ...

# %%
df
# Out:
#                        created_at                   id               id_str  \
# 0  Wed Apr 12 14:53:29 +0000 2023  1646164641452621833  1646164641452621833
# 1  Wed Apr 12 14:53:23 +0000 2023  1646164617188589570  1646164617188589570
# 2  Wed Apr 12 14:53:20 +0000 2023  1646164605293547526  1646164605293547526
# 3  Wed Apr 12 14:53:19 +0000 2023  1646164599509581832  1646164599509581832
# 4  Wed Apr 12 14:53:16 +0000 2023  1646164589040619522  1646164589040619522
# 5  Wed Apr 12 14:53:14 +0000 2023  1646164578131144705  1646164578131144705
# 6  Wed Apr 12 14:53:12 +0000 2023  1646164571575443463  1646164571575443463
# 7  Wed Apr 12 14:53:08 +0000 2023  1646164555553206278  1646164555553206278
# 8  Wed Apr 12 14:53:05 +0000 2023  1646164539090558976  1646164539090558976
# 9  Wed Apr 12 14:53:03 +0000 2023  1646164534460137473  1646164534460137473
#
#                                                 text  truncated  \
# 0  RT @RaffaellaRegoli: #fuoridalcoro #Covid “Ind...      False
# ...

# %%
df[10:20]
# Out:
# Empty DataFrame
# ...

# %%
auth = tweepy.OAuth1UserHandler(
    app_key,app_secret,oauth_token,oauth_token_secret
)

# Setting wait_on_rate_limit to True when initializing API will initialize an
# instance, called api here, that will automatically wait, using time.sleep,
# for the appropriate amount of time when a rate limit is encountered
api = tweepy.API(auth, wait_on_rate_limit=True)

# This will search for Tweets with the query "Twitter", returning up to the
# maximum of 100 Tweets per request to the Twitter API

# Once the rate limit is reached, it will automatically wait / sleep before
# continuing

for tweet in tweepy.Cursor(api.search_tweets, "Twitter", count=100).items():
    #print(tweet.id)

# %%
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

#q is QUERY WORD : looks for exact words in tweets, can do # and @ 
ftweets = api.search_tweets(
    #specify url for urls with specfic words in it
    q="url :beyonce",
    count=10
)
#print(ftweets)

# %%
#Using bunmi's method creating and saving file
json_data = [r._json for r in ftweets]

df = pd.json_normalize(json_data)
with open('beyonce.json', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('beyonce.json') as file:
    loaded = json.load(file)
    
bey_df = pd.DataFrame.from_dict(loaded["data"])

# %%
bey_df
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Apr 11 16:15:12 +0000 2023  1645822819958243334  1645822819958243334
# 1  Sat Apr 08 16:23:10 +0000 2023  1644737660320206851  1644737660320206851
# 2  Thu Apr 06 05:20:47 +0000 2023  1643846188225929217  1643846188225929217
# 3  Tue Apr 04 16:55:19 +0000 2023  1643296199187783696  1643296199187783696
# 4  Tue Apr 04 06:08:19 +0000 2023  1643133377011412992  1643133377011412992
# 5  Tue Apr 04 04:41:49 +0000 2023  1643111606077865984  1643111606077865984
#
#                                                 text  truncated  \
# 0  @blindma1den No confies, la url verdadera es h...      False
# 1  What's the 411? Beyonce’s mom Tina Knowles has...      False
# 2  Kim Kardashian Flaunts her curves in sultry wh...       True
# 3  She really just compared me to a lawn chair an...       True
# 4  @freetobeme6854 Anyone at anytime can direct a...       True
# ...

# %%
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

#q is QUERY WORD : looks for exact words in tweets, can do # and @ 
oloni_tweets = api.search_tweets(
    #specify url for urls with specfic words in it
    q="@Oloni",
    count=400
)
#print(oloni_tweets)

# %%
#REMEMEBER LATER CAN ONLY SCRAPE 100 TWEETS AT A TIME

json_data = [r._json for r in oloni_tweets]

df = pd.json_normalize(json_data)
with open('24_April_Oloni_tweets', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('24_April_Oloni_tweets') as file:
    loaded = json.load(file)
    
dating_1_df = pd.DataFrame.from_dict(loaded["data"])

# %%
dating_1_df
# Out:
#                         created_at                   id               id_str  \
# 0   Mon May 01 18:00:37 +0000 2023  1653097105387315214  1653097105387315214
# 1   Mon May 01 17:55:28 +0000 2023  1653095810765139969  1653095810765139969
# 2   Mon May 01 17:52:47 +0000 2023  1653095134869741583  1653095134869741583
# 3   Mon May 01 17:49:59 +0000 2023  1653094430671249408  1653094430671249408
# 4   Mon May 01 17:45:27 +0000 2023  1653093289392742401  1653093289392742401
# ..                             ...                  ...                  ...
# 95  Mon May 01 13:43:08 +0000 2023  1653032305764585473  1653032305764585473
# 96  Mon May 01 13:32:01 +0000 2023  1653029511129182210  1653029511129182210
# 97  Mon May 01 13:17:46 +0000 2023  1653025922574868482  1653025922574868482
# 98  Mon May 01 13:17:09 +0000 2023  1653025767977041921  1653025767977041921
# 99  Mon May 01 13:17:04 +0000 2023  1653025745113841667  1653025745113841667
#
# ...

# %%
dating_1_df.text[:100]
# Out:
# 0                    RT @Oloni: Happy Masturbation May.
# 1             RT @Oloni: God. My favourite show ever. 😭
# 2           RT @Oloni: What’s a friendship ick for you?
# 3                               RT @Oloni: Goodness me.
# 4                             RT @Oloni: I believe her.
#                             ...
# 95      RT @Oloni: If i scream. https://t.co/H6KiAUwBnG
# 96                            RT @Oloni: I believe her.
# 97    RT @Oloni: Nah sometimes i’m just clapping bk ...
# 98    RT @CStormyy: @Oloni Invading my privacy. Alwa...
# 99    RT @Katniss360: @Oloni Women who leave another...
# Name: text, Length: 100, dtype: object

# %%
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

#q is QUERY WORD : looks for exact words in tweets, can do # and @ 
TRP_tweets = api.search_tweets(
    #specify url for urls with specfic words in it
    q="#TheReceiptsPodcast",
    tweet_mode='extended',
    
    count=100
)
# Out:
# Unexpected parameter: country

# %%
json_data = [r._json for r in TRP_tweets]

df = pd.json_normalize(json_data)
with open('24_April_TRP_tweets', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('24_April_TRP_tweets') as file:
    loaded = json.load(file)
    
dating_2_TRP_df = pd.DataFrame.from_dict(loaded["data"])

# %%
dating_2_TRP_df
# Out:
#                         created_at                   id               id_str  \
# 0   Sun Apr 30 16:24:20 +0000 2023  1652710485786079234  1652710485786079234
# 1   Sun Apr 30 16:00:27 +0000 2023  1652704474777939969  1652704474777939969
# 2   Sun Apr 30 12:44:29 +0000 2023  1652655158025678848  1652655158025678848
# 3   Sun Apr 30 10:35:41 +0000 2023  1652622744087920640  1652622744087920640
# 4   Sun Apr 30 10:33:25 +0000 2023  1652622173549338624  1652622173549338624
# ..                             ...                  ...                  ...
# 95  Wed Apr 26 13:49:40 +0000 2023  1651222009907486720  1651222009907486720
# 96  Wed Apr 26 13:48:53 +0000 2023  1651221816130633731  1651221816130633731
# 97  Wed Apr 26 13:23:40 +0000 2023  1651215468919771141  1651215468919771141
# 98  Wed Apr 26 13:07:45 +0000 2023  1651211463023886337  1651211463023886337
# 99  Wed Apr 26 13:05:50 +0000 2023  1651210978963357697  1651210978963357697
#
# ...

# %%
#dating_1_df[["created_at",'text',"id","id_str",]]
no = 0
for tweet in TRP_tweets:
    # check if the tweet is a retweet
    if tweet.full_text.startswith('RT @'):
    # if the tweet is a retweet, use the retweeted_status attribute
        full_text = tweet.retweeted_status.full_text
    else:
        full_text = tweet.full_text
        print(full_text)
           
#find a way to ut full text with associated location in a sep table
# Out:
# #TheReceiptsPodcast Episode 171 https://t.co/P6tyBAo4Vp
# What a great evening at the #ISWISLondon live show and meeting 2/3 of the #TheReceiptsPodcast. Jollz and FK were hilarity personified as usual and although Tolly and I are the same age, it still felt like meeting my big sisters! Big feels tonight ❤️ https://t.co/FujqHhjawK
# It’s Milena casually saying that the guy who used to spoil her used to steal the money from the bank he worked at for me 🤣 #TheReceiptsPodcast
#
#  https://t.co/kVWXgqwsrZ
# This weeks episode of #TheReceiptsPodcast talk on therapy was so validating, it’s good to know I ain’t going crazy🥴
# I love it when #TheReceiptsPodcast reminisce about old school pop music. The best era in music man
# ...

# %%
print(full_text)
# Out:
# #Thereceiptspodcast is so right about ppl using therapy/therapy jargon to become actual dickheads. Half of you can't even afford therapy but you're throwing around these words to serve your delinquency without having a licensed therapist guide you in applying these principles.

# %%
#with open('The Recepts Pod Tweets_1', 'w', newline='') as file:
#writer = csv.writer(file)
#    field = ["text"]
    
#    writer.writerow(field)

# %%
# First you get the tweets in a json object

results = api.search_tweets(
    #specify url for urls with specfic words in it
    q="dating is ghetto",
   
    count=100,
    lang='en'
)
print(results)
# Now you can iterate over 'results' and store the complete message from each tweet.
#my_tweets = []
#for result in dating_2_TRP_df:
#    my_tweets.append(dating_2_TRP_df["full_text"])
#print(my_tweets)
# Out:
# [Status(_api=<tweepy.api.API object at 0x1248f96d0>, _json={'created_at': 'Tue May 02 15:06:14 +0000 2023', 'id': 1653415608132808704, 'id_str': '1653415608132808704', 'text': 'The dating world is ghetto', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3235672814, 'id_str': '3235672814', 'name': 'Babycash💎', 'screen_name': 'QueeningTvylor', 'location': 'Cancer 🌞Pisces 🌙Libra♎️', 'description': 'Spoil me or leave me alone .', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3127, 'friends_count': 2739, 'listed_count': 7, 'created_at': 'Thu Jun 04 03:57:06 +0
# ...

# %%
dating_1_df["text"][20]
# Out:
# Series([], Name: text, dtype: object)

# %%
with open('Tinder_1') as file:
    l = json.load(file)
    
d = pd.DataFrame.from_dict(l["data"])

# %%
d
# Out:
#                         created_at                   id               id_str  \
# 0   Tue May 02 17:13:43 +0000 2023  1653447688052932613  1653447688052932613
# 1   Tue May 02 17:13:38 +0000 2023  1653447669153398810  1653447669153398810
# 2   Tue May 02 17:13:38 +0000 2023  1653447667219824643  1653447667219824643
# 3   Tue May 02 17:13:32 +0000 2023  1653447641898860544  1653447641898860544
# 4   Tue May 02 17:13:30 +0000 2023  1653447633850048513  1653447633850048513
# ..                             ...                  ...                  ...
# 93  Tue May 02 16:55:23 +0000 2023  1653443077237768206  1653443077237768206
# 94  Tue May 02 16:55:13 +0000 2023  1653443034703446016  1653443034703446016
# 95  Tue May 02 16:55:10 +0000 2023  1653443020820234240  1653443020820234240
# 96  Tue May 02 16:55:01 +0000 2023  1653442983025430531  1653442983025430531
# 97  Tue May 02 16:54:55 +0000 2023  1653442959445200897  1653442959445200897
#
# ...

# %%
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

places = api.search_geo(query="London", granularity="city")
for place in places:    
    pass
#q is QUERY WORD : looks for exact words in tweets, can do # and @ 
dating_ad_tweets = api.search_tweets(
    #specify url for urls with specfic words in it
    q="place:%s" % place.id and "dating advice",
    count=400
)
#print(oloni_tweets)

# %%
json_data = [r._json for r in dating_ad_tweets]

df = pd.json_normalize(json_data)
with open('18_May_DatingAdvice', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('18_May_DatingAdvice') as file:
    loaded = json.load(file)
    
DA = pd.DataFrame.from_dict(loaded["data"])

# %%
DA
# Out:
#                         created_at                   id               id_str  \
# 0   Thu May 18 15:19:29 +0000 2023  1659217148617584640  1659217148617584640
# 1   Thu May 18 15:18:43 +0000 2023  1659216954165534720  1659216954165534720
# 2   Thu May 18 15:18:27 +0000 2023  1659216889644556288  1659216889644556288
# 3   Thu May 18 15:17:11 +0000 2023  1659216569245761536  1659216569245761536
# 4   Thu May 18 15:09:41 +0000 2023  1659214683793137665  1659214683793137665
# ..                             ...                  ...                  ...
# 95  Thu May 18 05:24:20 +0000 2023  1659067372634873857  1659067372634873857
# 96  Thu May 18 05:20:58 +0000 2023  1659066527986098176  1659066527986098176
# 97  Thu May 18 05:12:42 +0000 2023  1659064446382219264  1659064446382219264
# 98  Thu May 18 05:09:40 +0000 2023  1659063682662559744  1659063682662559744
# 99  Thu May 18 05:06:39 +0000 2023  1659062923279335428  1659062923279335428
#
# ...

# %%
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

places = api.search_geo(query="London", granularity="city")
for place in places:    
    pass
#q is QUERY WORD : looks for exact words in tweets, can do # and @ 
dating_stories_tweets = api.search_tweets(
    #specify url for urls with specfic words in it
    q="place:%s" % place.id and "dating stories-filter:retweets",
    count=400
)
#print(oloni_tweets)

# %%
json_data = [r._json for r in dating_stories_tweets]

df = pd.json_normalize(json_data)
with open('18_May_DatingStories', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('18_May_DatingStories') as file:
    loaded = json.load(file)
    
ds = pd.DataFrame.from_dict(loaded["data"])

# %%
ds
# Out:
#                         created_at                   id               id_str  \
# 0   Thu May 18 15:15:18 +0000 2023  1659216096648470528  1659216096648470528
# 1   Thu May 18 14:49:43 +0000 2023  1659209657754472449  1659209657754472449
# 2   Thu May 18 14:47:13 +0000 2023  1659209028172660740  1659209028172660740
# 3   Thu May 18 14:46:40 +0000 2023  1659208891002146823  1659208891002146823
# 4   Thu May 18 14:44:11 +0000 2023  1659208265434296327  1659208265434296327
# ..                             ...                  ...                  ...
# 95  Wed May 17 13:15:39 +0000 2023  1658823596343541761  1658823596343541761
# 96  Wed May 17 13:04:59 +0000 2023  1658820911904989184  1658820911904989184
# 97  Wed May 17 12:58:56 +0000 2023  1658819391130341376  1658819391130341376
# 98  Wed May 17 12:49:12 +0000 2023  1658816940771606528  1658816940771606528
# 99  Wed May 17 12:32:32 +0000 2023  1658812747725918210  1658812747725918210
#
# ...

# %%
for i in ds["text"]:
    print(i)
# Out:
# From dating paintings that use Prussian blue to studying the layers of paint like an archaeologist digging a site,… https://t.co/OvNIq1SDau
# One of these days I need to tell my dating horror stories!!!
# nevermind…he just posted stories of his new girlfriend and they’ve been dating for months.
# [Thread] About #TAENNIE dating rumor and "@/akio_v_1" on IG.
#
# First of all, I'm still doubtful whether it was real… https://t.co/gh9RUTPyQb
# Our Tempted by the Tycoon Collection is out now!
#
# Featuring six seductive and scandalous stories. With the fake dat… https://t.co/y2G8LWGmPW
# TW :  TSA testing facial recognition technology, prompting privacy concerns: ...Trending stories at Scrippsnews.com… https://t.co/f40YLu7z6Q
# 'Bad Dating Stories' Casting Notice is now LIVE on https://t.co/aOeB7XZA6N! Share your cringe-worthy, nerve-wrackin… https://t.co/0DSBY6wYwO
# ...

# %%
doc = nlp(open("Tinder_1").read())

# %%
tokens = list(set([w.text for w in doc if w.is_alpha and w.has_vector]))

# %%
def vec(s):
    return nlp(s).vector

# %%
def cosine_similarity(vec1,vec2): 
    return 1- spatial.distance.cosine(vec1,vec2)

# %%
# run the below to have words in spacy cache for vocab
random_words = nlp('house good pizza cars fun chess vegetable fries of apple juice kingdom burger prince house wicked this banana home island car truck dog rice')

# %%
# Words to Vectors
food = nlp('food')
fruit = nlp('fruit')
burger = nlp('burger')

# %%
food_fruit = food.similarity(fruit)
fruit_burger = fruit.similarity(burger)
food_burger = food.similarity(burger)

# %%
print(f"Food Fruit similarity: {food_fruit}")
print(f"Fruit Burger similarity: {fruit_burger}")
print(f"Food Burger similarity: {food_burger}")
# Out:
# Food Fruit similarity: 0.4990189967128146
# Fruit Burger similarity: 0.29312107791773295
# Food Burger similarity: 0.4319428867481376

# %%
new_vector = food.vector-burger.vector+fruit.vector
new_vector
# Out:
# array([ 3.86609983e+00, -1.14630394e+01, -1.04129009e+01,  6.49167538e+00,
#         2.34700012e+00, -1.83385010e+01, -2.69965005e+00,  4.01448011e+00,
#        -9.59350014e+00,  1.72939956e-01,  7.17580032e+00, -8.02441025e+00,
#        -2.66123009e+00,  7.64300108e-01, -1.93001997e+00, -5.95269966e+00,
#         7.62818003e+00, -1.05038004e+01, -7.25900030e+00, -1.45079203e+01,
#        -3.95908928e+00,  8.15380001e+00, -9.48737621e+00, -4.04794979e+00,
#        -3.61350608e+00, -5.45765972e+00, -1.03656006e+01,  6.84480000e+00,
#        -6.43560028e+00,  2.65104795e+00,  9.94439983e+00, -9.33155060e+00,
#        -2.47079992e+00, -7.79569006e+00,  4.14389968e-01, -1.01316023e+00,
#         9.97231007e+00,  3.42899990e+00,  1.24670005e+00, -2.71990991e+00,
#        -3.71840000e+00,  3.23818398e+00,  1.24307003e+01,  8.33302021e+00,
#        -2.13500142e-01,  5.35362005e+00,  7.54390001e+00, -1.93480015e+00,
# ...

# %%
# Given a group of words see which word is closet

similarities = []
for word in random_words:
    if word.has_vector and word.is_alpha and word.is_lower:
        similarities.append((cosine_similarity(new_vector,word.vector),word.text, word))

# %%
print(sorted(similarities, reverse=True)[:10])
# Out:
# [(0.7023036479949951, 'vegetable', vegetable), (0.5161346197128296, 'rice', rice), (0.48890525102615356, 'apple', apple), (0.4708367586135864, 'juice', juice), (0.4511953294277191, 'banana', banana), (0.34203433990478516, 'fries', fries), (0.2719743549823761, 'home', home), (0.25531521439552307, 'pizza', pizza), (0.25449636578559875, 'good', good), (0.2506324350833893, 'this', this)]

# %%
cosine_similarity(vec('dog'), vec('puppy')) > cosine_similarity(vec('trousers'), vec('octopus'))
# Out:
# True

# %%
def spacy_closest(token_list, vec_to_check, n=10):
    return sorted(token_list,
                  key=lambda x: cosine_similarity(vec_to_check, vec(x)),
                  reverse=True)[:n]

# %%
spacy_closest(tokens, vec("talking stage"),30)
# Out:
# ['talking',
#  'thinking',
#  'watching',
#  'playing',
#  'wondering',
#  'influencing',
#  'conversation',
#  'looking',
#  'doing',
#  'time',
#  'really',
#  'working',
#  'laughing',
#  'basically',
#  'planning',
#  'phase',
#  'thing',
#  'going',
#  'thoughts',
#  'though',
#  'especially',
#  'darting',
#  'liking',
#  'think',
#  'scene',
#  'Coincidentally',
#  'conversations',
#  'meeting',
#  'hooking',
#  'right']
