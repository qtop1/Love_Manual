# %%
#************* scrape green flags and red flags (synomyn of do's and don'ts ) ***************
import configparser
import tweepy

from T_config import *

import requests
import json
import pandas as pd


import nltk
nltk.download('stopwords')
nltk.download('vader_lexicon')
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.sentiment import SentimentIntensityAnalyzer
import string

import csv

import spacy
from scipy import spatial
import matplotlib.pyplot as plt
import numpy as np

import random as ran
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jalisaabeid/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jalisaabeid/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
 nlp = spacy.load('en_core_web_lg')

# %%
#Authentication
auth = tweepy.OAuthHandler(app_key,app_secret)
auth.set_access_token(oauth_token,oauth_token_secret)

api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
#Dating Rules Scrape

# %%
#Getting tweets from specfic country
#Ref : https://stackoverflow.com/questions/50779161/why-these-two-apistwitter-geo-search-apis-return-different-result-set

#Includes RETWEETS
places = api.search_geo(query="London", granularity="city")
for place in places:    
    pass
public_tweets = api.search_tweets(count=100,q="place:%s" % place.id and "dating rules",tweet_mode="extended",lang = "en")

#Convert to JSON
json_data = [r._json for r in public_tweets]
df = pd.json_normalize(json_data)
    
    
with open('Dating_Rules_1', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('Dating_Rules_1') as file:
    q = json.load(file)
    
dr = pd.DataFrame.from_dict(q["data"])

# %%
dr
# Out:
#                         created_at                   id               id_str  \
# 0   Mon May 29 13:42:44 +0000 2023  1663179066512400387  1663179066512400387
# 1   Mon May 29 13:42:14 +0000 2023  1663178941434146816  1663178941434146816
# 2   Mon May 29 13:35:24 +0000 2023  1663177221241028610  1663177221241028610
# 3   Mon May 29 13:33:51 +0000 2023  1663176829413326849  1663176829413326849
# 4   Mon May 29 12:18:26 +0000 2023  1663157853149102081  1663157853149102081
# ..                             ...                  ...                  ...
# 95  Sun May 28 18:47:26 +0000 2023  1662893360774774793  1662893360774774793
# 96  Sun May 28 18:36:12 +0000 2023  1662890531331141634  1662890531331141634
# 97  Sun May 28 18:12:04 +0000 2023  1662884459002183683  1662884459002183683
# 98  Sun May 28 18:05:29 +0000 2023  1662882803615256578  1662882803615256578
# 99  Sun May 28 18:03:00 +0000 2023  1662882175346425856  1662882175346425856
#
# ...

# %%
#get the full text section and randomly generate/get the text 
my_list = []
for i in dr["full_text"]:
    my_list.append(i)

# %%
# Seperated and evenly spaced 
board = []
for i in dr["full_text"]:
    temp = []
    temp.append(i)
    board.append(temp)

for new in board:
    print (''.join(new))
# Out:
# RT @TruthSeeker84x3: And they wonder why they're still single!!
#
# Singletons reveal 'non-negotiable' dating rules https://t.co/tVXu8Mwdbx v…
# And they wonder why they're still single!!
#
# Singletons reveal 'non-negotiable' dating rules https://t.co/tVXu8Mwdbx via https://t.co/cfCdWOrqpz
# RT @wonwoncity: ❝ before we start dating, let’s set some rules. listen to me over big matters, listen to you over small matters ❞
#
# ❝ what i…
# RT @robkhenderson: "male height, the absence of it, is one of the last social stigmas, as if the new rules of body positivity fail to apply…
# RT @wonwoncity: ❝ before we start dating, let’s set some rules. listen to me over big matters, listen to you over small matters ❞
#
# ❝ what i…
# Singletons reveal 'non-negotiable' dating rules https://t.co/Xu3CLUgR47
# RT @UnniesKM: Hello everyone, this is me again KFam new owner.
# So today I decided to re-open this Twitter, kasi sayang naman if ghosted na…
# ...

# %%
#randomly generate/get the text 
picked = ran.choice(board)
print(picked)
# Out:
# ['RT @robkhenderson: "male height, the absence of it, is one of the last social stigmas, as if the new rules of body positivity fail to apply…']

# %%
#WITHOUT RETWEET
#-filter:retweets
places = api.search_geo(query="London", granularity="city")
for place in places:    
    pass
public_tweets = api.search_tweets(count=100,q="place:%s" % place.id and "dating rules-filter:retweets",tweet_mode="extended",lang = "en")

#Convert to JSON
json_data = [r._json for r in public_tweets]
df = pd.json_normalize(json_data)
    
    
with open('Dating_Rules_1_wo_retweets', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('Dating_Rules_1_wo_retweets') as file:
    q = json.load(file)
    
re_dr = pd.DataFrame.from_dict(q["data"])

# %%
re_dr
# Out:
#                         created_at                   id               id_str  \
# 0   Mon May 29 13:42:14 +0000 2023  1663178941434146816  1663178941434146816
# 1   Mon May 29 12:05:27 +0000 2023  1663154583923744769  1663154583923744769
# 2   Mon May 29 11:55:03 +0000 2023  1663151966573281280  1663151966573281280
# 3   Mon May 29 11:49:32 +0000 2023  1663150578510299136  1663150578510299136
# 4   Mon May 29 10:07:12 +0000 2023  1663124826142253063  1663124826142253063
# ..                             ...                  ...                  ...
# 95  Fri May 26 11:18:56 +0000 2023  1662055712971796481  1662055712971796481
# 96  Fri May 26 09:57:44 +0000 2023  1662035278981201922  1662035278981201922
# 97  Fri May 26 09:04:23 +0000 2023  1662021852091523072  1662021852091523072
# 98  Fri May 26 09:03:34 +0000 2023  1662021646847299584  1662021646847299584
# 99  Fri May 26 08:42:35 +0000 2023  1662016368177303552  1662016368177303552
#
# ...

# %%
sec_board = []
for i in re_dr["full_text"]:
    temp = []
    temp.append(i)
    sec_board.append(temp)

for new in sec_board:
    print (' '.join(new))
# Out:
# And they wonder why they're still single!!
#
# Singletons reveal 'non-negotiable' dating rules https://t.co/tVXu8Mwdbx via https://t.co/cfCdWOrqpz
# Singletons reveal 'non-negotiable' dating rules https://t.co/Xu3CLUgR47
# Does migraine drive a wedge between you and your love life? Read on for tips on managing sex, dating and relationships with migraine.  https://t.co/afnNHeEhMI
# @Sound_Resident It's absolutely ridiculous how the madness of this is all being forced upon us. They act like it's a job interview having to abide employment rules instead of a dating/personals advertisement that those rules don't apply. https://t.co/t2zmKCowol
# Just think about a dating experience where the community has a say in the matchmaking rules.👩&lt;-&gt;👨
# And users would have more control over their dating journey, ensuring a personalized and empowering experience.
# Retweet and share this with your single friends!😉
#  #DAO #dating https://t.co/CwOo6Epv5D
# ...

# %%
#randomly generate/get the text 
picked = ran.choice(sec_board)
print(picked)
# Out:
# ["@Sound_Resident It's absolutely ridiculous how the madness of this is all being forced upon us. They act like it's a job interview having to abide employment rules instead of a dating/personals advertisement that those rules don't apply. https://t.co/t2zmKCowol"]

# %%
#**************************** DATING DOS SECTION SCRAPING *******************************

# %%
#open to all regions
public_tweets = api.search_tweets(count=100,q="relationship green flags",tweet_mode="extended",lang = "en")

#Convert to JSON
json_data = [r._json for r in public_tweets]
df = pd.json_normalize(json_data)
    
    
with open('random', 'w') as outfile:
    tweets_json = {"data": json_data}
    json.dump(tweets_json, outfile)

# %%
with open('random') as file:
    q = json.load(file)
    
everywhere = pd.DataFrame.from_dict(q["data"])

# %%
everywhere
# Out:
#                         created_at                   id               id_str  \
# 0   Mon May 29 16:28:13 +0000 2023  1663220712298147842  1663220712298147842
# 1   Mon May 29 15:04:54 +0000 2023  1663199742401060865  1663199742401060865
# 2   Mon May 29 12:41:16 +0000 2023  1663163597923536896  1663163597923536896
# 3   Mon May 29 11:11:25 +0000 2023  1663140986069954562  1663140986069954562
# 4   Mon May 29 06:46:38 +0000 2023  1663074352315744257  1663074352315744257
# ..                             ...                  ...                  ...
# 95  Sat May 20 20:03:08 +0000 2023  1660013305690222592  1660013305690222592
# 96  Sat May 20 19:55:05 +0000 2023  1660011280793587713  1660011280793587713
# 97  Sat May 20 19:54:57 +0000 2023  1660011245632618496  1660011245632618496
# 98  Sat May 20 19:54:38 +0000 2023  1660011168986189824  1660011168986189824
# 99  Sat May 20 19:45:52 +0000 2023  1660008960382861315  1660008960382861315
#
# ...

# %%
# Seperated and evenly spaced 
four_board = []
for i in everywhere["full_text"]:
    temp = []
    temp.append(i)
    board.append(temp)

for new in four_board:
    print (''.join(new))

# %%
third_board = []
for i in everywhere["full_text"]:
    temp = []
    temp.append(i)
    third_board.append(temp)

# %%
#randomly generate/get the text 
picked = ran.choice(third_board)
print(picked)
# Out:
# ['27 Green Flags in a Relationship https://t.co/SiEk6xCGSE']
